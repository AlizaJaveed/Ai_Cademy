# %%
# Activity 1: To-Do List Organizer
# Initialize an empty to-do list
to_do_list = []
while True:
    # Menu for the user
    print("\nTo-Do List Organizer Menu:")
    print("1. Add a Task")
    print("2. Mark a Task as Completed")
    print("3. Remove Completed Tasks")
    print("4. View To-Do List")
    print("5. Exit")
    choice = input("Enter your choice: ")
    if choice == "1":
        task = input("Enter the task: ")
        to_do_list.append({"task": task, "completed": False})
        print(f"Task ’{task}’ added to the to-do list.")
    elif choice == "2":
        task_index = int(input("Enter the task index to mark as completed: "))
        if 0 <= task_index < len(to_do_list):
            to_do_list[task_index]["completed"] = True
            print("Task marked as completed.")
        else:
            print("Invalid task index.")
    elif choice == "3":
        to_do_list = [task for task in to_do_list if not task["completed"]]
        print("Completed tasks removed.")
    elif choice == "4":
        for i, task in enumerate(to_do_list):
            status = "Completed" if task["completed"] else "To-Do"
            print(f"{i}. {task['task']} - {status}")
    elif choice == "5":
        print("Exiting the To-Do List Organizer.")
        break
    else:
        print("Invalid choice. Please select a valid option.")
# Out:
# To-Do List Organizer Menu:
# 1. Add a Task
# 2. Mark a Task as Completed
# 3. Remove Completed Tasks
# 4. View To-Do List
# 5. Exit
# Enter your choice: 1
# Enter the task: 121
# Task ’121’ added to the to-do list.
#
# To-Do List Organizer Menu:
# 1. Add a Task
# 2. Mark a Task as Completed
# 3. Remove Completed Tasks
# 4. View To-Do List
# 5. Exit
# Enter your choice: 5
# Exiting the To-Do List Organizer.

# %%
# Activity 2: Shopping List
# Initialize an empty shopping list
shopping_list = []
while True:
    print("\nShopping List Menu:")
    print("1. Add an Item")
    print("2. View Shopping List")
    print("3. Remove an Item")
    print("4. Exit")
    choice = input("Enter your choice: ")
    if choice == "4":
        print("Exiting the Shopping List.")
        break
    if choice == "1":
        item = input("Enter an item to add to the shopping list: ")
        shopping_list.append(item)
        print(f"Item ’{item}’ added to the shopping list.")
    elif choice == "2":
        if not shopping_list:
            print("Shopping list is empty.")
        else:
            print("\nShopping List:")
            for i, item in enumerate(shopping_list):
                print(f"{i}. {item}")
    elif choice == "3":
        if not shopping_list:
            print("Shopping list is empty; nothing to remove.")
        else:
            item_to_remove = input("Enter the name of the item to remove: ")
            if item_to_remove in shopping_list:
                shopping_list.remove(item_to_remove)
                print(f"Item ’{item_to_remove}’ removed from the shopping list.")
            else:
                print(f"Item ’{item_to_remove}’ not found in the shopping list.")
    else:
        print("Invalid choice. Please select a valid option.")
# Out:
# Shopping List Menu:
# 1. Add an Item
# 2. View Shopping List
# 3. Remove an Item
# 4. Exit
# Enter your choice: 3
# Shopping list is empty; nothing to remove.
#
# Shopping List Menu:
# 1. Add an Item
# 2. View Shopping List
# 3. Remove an Item
# 4. Exit
# Enter your choice: 4
# Exiting the Shopping List.

# %%
# Activity 3: Contact Information
# Initialize an empty list to store contacts
contacts = []
index = 0 # Initialize an index variable
while True:
    print("\nContact Information Menu:")
    print("1. Add a Contact")
    print("2. View Contacts")
    print("3. Remove a Contact")
    print("4. Exit")
    choice = input("Enter your choice: ")
    if choice == "4":
        print("Exiting the Contact Information.")
        break
    if choice == "1":
        name = input("Enter the contact’s name: ")
        phone = input("Enter the contact’s phone number: ")
        contact = (name, phone)
        contacts.append(contact)
        print(f"Contact ’{name}’ added.")
    elif choice == "2":
        if not contacts:
            print("No contacts to display.")
        else:
            print("\nContacts:")
            while index < len(contacts):
                name, phone = contacts[index]
                print(f"{index}. Name: {name}, Phone: {phone}")
                index += 1
            index = 0 
    elif choice == "3":
        if not contacts:
            print("No contacts to remove.")
        else:
            contact_index = int(input("Enter the contact index to remove: "))
            if 0 <= contact_index < len(contacts):
                name, phone = contacts.pop(contact_index)
                print(f"Contact ’{name}’ removed.")
            else:
                print("Invalid contact index.")
    else:
        print("Invalid choice. Please select a valid option.")
# Out:
# Contact Information Menu:
# 1. Add a Contact
# 2. View Contacts
# 3. Remove a Contact
# 4. Exit
# Enter your choice: 1
# Enter the contact’s name: marisha
# Enter the contact’s phone number: 030000000000
# Contact ’marisha’ added.
#
# Contact Information Menu:
# 1. Add a Contact
# 2. View Contacts
# 3. Remove a Contact
# 4. Exit
# Enter your choice: 2
#
# Contacts:
# 0. Name: marisha, Phone: 030000000000
#
# Contact Information Menu:
# 1. Add a Contact
# 2. View Contacts
# 3. Remove a Contact
# 4. Exit
# Enter your choice: 3
# Enter the contact index to remove: 1
# Invalid contact index.
#
# Contact Information Menu:
# 1. Add a Contact
# 2. View Contacts
# 3. Remove a Contact
# 4. Exit
# Enter your choice: 4
# Exiting the Contact Information.

# %%
# Activity 4: Student Grades
# Initialize an empty list to store student information (name, grades)
students = []
student_index = 0 # Initialize a student index variable
while True:
    print("\nStudent Grades Menu:")
    print("1. Add a Student")
    print("2. View Student Grades")
    print("3. Calculate Average Grades")
    print("4. Exit")
    choice = input("Enter your choice: ")
    if choice == "4":
        print("Exiting the Student Grades.")
        break
    if choice == "1":
        name = input("Enter the student’s name: ")
        grades_input = input("Enter the student’s grades (comma-separated): ")
        grades = [float(grade) for grade in grades_input.split(',')]
        student = (name, grades)
        students.append(student)
        print(f"Student ’{name}’ added.")
    elif choice == "2":
        if not students:
            print("No students to display.")
        else:
            print("\nStudents and Their Grades:")
        while student_index < len(students):
            name, grades = students[student_index]
            grade_str = ','.join(map(str, grades))
            print(f"Name: {name}, Grades: {grade_str}")
            student_index += 1
        student_index = 0 # Reset the student index after displaying all
    elif choice == "3":
        if not students:
            print("No students to calculate average grades for.")
        else:
            name = input("Enter the student’s name to calculate average grades: ")
            for student_name, student_grades in students:
                if student_name == name:
                    average = sum(student_grades) / len(student_grades)
                    print(f"Average grades for {name}: {average:.2f}")
                    break
            else:
                print(f"Student ’{name}’ not found.")
    else:
        print("Invalid choice. Please select a valid option.")
# Out:
# Student Grades Menu:
# 1. Add a Student
# 2. View Student Grades
# 3. Calculate Average Grades
# 4. Exit
# Enter your choice: 1
# Enter the student’s name: marisha
# Enter the student’s grades (comma-separated): 4.00
# Student ’marisha’ added.
#
# Student Grades Menu:
# 1. Add a Student
# 2. View Student Grades
# 3. Calculate Average Grades
# 4. Exit
# Enter your choice: maria
# Invalid choice. Please select a valid option.
#
# Student Grades Menu:
# 1. Add a Student
# 2. View Student Grades
# 3. Calculate Average Grades
# 4. Exit
# Enter your choice: 1
# Enter the student’s name: maria
# Enter the student’s grades (comma-separated): 3.89
# Student ’maria’ added.
#
# Student Grades Menu:
# 1. Add a Student
# 2. View Student Grades
# 3. Calculate Average Grades
# 4. Exit
# Enter your choice: 2
#
# Students and Their Grades:
# Name: marisha, Grades: 4.0
# Name: maria, Grades: 3.89
#
# Student Grades Menu:
# 1. Add a Student
# 2. View Student Grades
# 3. Calculate Average Grades
# 4. Exit
# Enter your choice: 3
# Enter the student’s name to calculate average grades: maria
# Average grades for maria: 3.89
#
# Student Grades Menu:
# 1. Add a Student
# 2. View Student Grades
# 3. Calculate Average Grades
# 4. Exit
# Enter your choice: 4
# Exiting the Student Grades.

# %%
# Activity 5: Finding Unique Letters
sentence = input("Enter a sentence: ")
letters = set()
for char in sentence:
    if char.isalpha():
        letters.add(char)
print("\nUnique Letters:")
for letter in letters:
    print(letter)
# Out:
# Enter a sentence: Finding
#
# Unique Letters:
# i
# d
# F
# n
# g

# %%
# Activity 6: Building a Simple Dictionary
# Initialize an empty Python dictionary for word meanings
dictionary = {}
while True:
    print("\nSimple Word Dictionary Menu:")
    print("1. Add a Word Meaning")
    print("2. Lookup Definition")
    print("3. Remove a Word")
    print("4. Exit")
    choice = input("Enter your choice: ")
    if choice == "4":
        print("Exiting the Simple Word Dictionary.")
        break
    if choice == "1":
        word = input("Enter a word: ")
        meaning = input("Enter the word’s meaning: ")
        dictionary[word] = meaning
        print(f"Word ’{word}’ added with meaning: ’{meaning}’.")
    elif choice == "2":
        word = input("Enter a word to look up: ")
        meaning = dictionary.get(word)
        if meaning:
            print(f"Meaning of ’{word}’: {meaning}")
        else:
            print(f"No meaning found for ’{word}’.")
    elif choice == "3":
        word = input("Enter a word to remove: ")
        if word in dictionary:
            del dictionary[word]
            print(f"Word ’{word}’ removed from the dictionary.")
        else:
            print(f"No word found for ’{word}’.")
    else:
        print("Invalid choice. Please select a valid option.")
# Out:
# Simple Word Dictionary Menu:
# 1. Add a Word Meaning
# 2. Lookup Definition
# 3. Remove a Word
# 4. Exit
# Enter your choice: 1
# Enter a word: cool
# Enter the word’s meaning: hot
# Word ’cool’ added with meaning: ’hot’.
#
# Simple Word Dictionary Menu:
# 1. Add a Word Meaning
# 2. Lookup Definition
# 3. Remove a Word
# 4. Exit
# Enter your choice: 2
# Enter a word to look up: smart
# No meaning found for ’smart’.
#
# Simple Word Dictionary Menu:
# 1. Add a Word Meaning
# 2. Lookup Definition
# 3. Remove a Word
# 4. Exit
# Enter your choice: 2
# Enter a word to look up: cool
# Meaning of ’cool’: hot
#
# Simple Word Dictionary Menu:
# 1. Add a Word Meaning
# 2. Lookup Definition
# 3. Remove a Word
# 4. Exit
# Enter your choice: 3
# Enter a word to remove: hot
# No word found for ’hot’.
#
# Simple Word Dictionary Menu:
# 1. Add a Word Meaning
# 2. Lookup Definition
# 3. Remove a Word
# 4. Exit
# Enter your choice: 4
# Exiting the Simple Word Dictionary.

# %%
# Activity 7: Health Science Research Data Analysis
# Initialize lists for patient data
patients = []
while True:
    print("\nHealth Science Research Data Analysis Menu:")
    print("1. Add a Patient")
    print("2. View Patient Data")
    print("3. Analyze Data")
    print("4. Exit")
    choice = input("Enter your choice: ")
    if choice == "4":
        print("Exiting the Health Science Research Data Analysis program.")
        break
    if choice == "1":
        patient_name = input("Enter the patient’s name: ")
        age = int(input("Enter the patient’s age: "))
        vitals = {
        "Heart Rate": int(input("Enter the heart rate: ")),
        "Blood Pressure": input("Enter the blood pressure (e.g., 120/80): "),
        "Temperature": float(input("Enter the temperature in Celsius: "))
        }
        patient = {
        "Name": patient_name,
        "Age": age,
        "Vitals": vitals
        }
        patients.append(patient)
        print(f"Patient '{patient_name}' added to the data.")
    elif choice == "2":
        if not patients:
            print("No patient data available.")
        else:
            print("\nPatient Data:")
            for patient in patients:
                print(f"Name: {patient['Name']}, Age: {patient['Age']}")
                vitals = patient['Vitals']
                print(f"Heart Rate: {vitals['Heart Rate']}, Blood Pressure: {vitals['Blood Pressure']}, Temperature: {vitals['Temperature']}")
    elif choice == "3":
        if not patients:
            print("No patient data available for analysis.")
        else:
            # Implement data analysis or calculations here
            pass
    else:
        print("Invalid choice. Please select a valid option.")
# Out:
# Health Science Research Data Analysis Menu:
# 1. Add a Patient
# 2. View Patient Data
# 3. Analyze Data
# 4. Exit
# Enter your choice: 1
# Enter the patient’s name: saad
# Enter the patient’s age: 32
# Enter the heart rate: 23
# Enter the blood pressure (e.g., 120/80): 89
# Enter the temperature in Celsius: 32
# Patient 'saad' added to the data.
#
# Health Science Research Data Analysis Menu:
# 1. Add a Patient
# 2. View Patient Data
# 3. Analyze Data
# 4. Exit
# Enter your choice: 2
#
# Patient Data:
# Name: saad, Age: 32
# Heart Rate: 23, Blood Pressure: 89, Temperature: 32.0
#
# Health Science Research Data Analysis Menu:
# 1. Add a Patient
# 2. View Patient Data
# 3. Analyze Data
# 4. Exit
# Enter your choice: 3
#
# Health Science Research Data Analysis Menu:
# 1. Add a Patient
# 2. View Patient Data
# 3. Analyze Data
# 4. Exit
# Enter your choice: 3
#
# Health Science Research Data Analysis Menu:
# 1. Add a Patient
# 2. View Patient Data
# 3. Analyze Data
# 4. Exit
# Enter your choice: 4
# Exiting the Health Science Research Data Analysis program.
